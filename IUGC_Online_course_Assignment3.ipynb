# %%
from obspy.imaging.beachball import beachball

# %%
# mt = [strike, dip, rake]
# strike slip fault
mt3 = [164, 80, -180] #201607100931A
beachball(mt3, size=200, linewidth=2, facecolor='g')

# %%
# thrust fault
mt = [320, 21, 90] #201402221729A
beachball(mt, size=200, linewidth=2, facecolor='b')

# %%
# shallow thurst fault
mt = [307, 7, 88] #201004062215A
beachball(mt, size=200, linewidth=2, facecolor='b')

# %%
# normal fault
mt2 = [323, 38, -92] #201010270004A
beachball(mt2, size=200, linewidth=2, facecolor='r')

# %%
# oblique fault
mt2 = [71,	42,	128] #201709242010A
beachball(mt2, size=200, linewidth=2, facecolor='y')

# %%
#mt = [M11, M22, M33, M12, M13, M23] 
        # the six independent components of the moment tensor, 
        # where the coordinate system is 1,2,3 = Up,South,East
        # which equals r,theta,phi
#normal fault
mt2 = [-4.93,1.77,3.16,-0.62,1.07,-2.12] #201010270004A
beachball(mt2, size=200, linewidth=2, facecolor='r')

# %%
# strike slip fault
mt3 = [-0.82,-1.88,2.7,-0.71,-0.41,3.75] #201607100931A 
beachball(mt3, size=200, linewidth=2, facecolor='g')

# %%
# thrust fault
mt = [0.96,-0.4,-0.56,0.65,-0.79,0.46] #201402221729A
beachball(mt, size=200, linewidth=2, facecolor='b')
